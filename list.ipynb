# %%
list=["siri","shruthi"]
it=iter(list)           #iteration (iter)
print(next(it))
print(next(it))
# Out:
# siri
# shruthi

# %%
list=[1,2,4,6,8,9,6,4,3]
it=iter(list)          
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# 1
# 2
# 4
# 6
