# %%
class Car:
    color = "red"
    name = "BMW"

Car1 = Car()
print(Car1.color)
print(Car1.name)
# Out:
# red
# BMW

# %%
class Mybook:
      pages = "50"
      topic = "globe"
library = Mybook()
print(library.pages)
print(library.topic)
# Out:
# 50
# globe

# %%
class student:
    def __init__(self,name,age):
      self.name = name
      self.age = age

s1 = student("shruthi",20)
print(s1.name)
# Out:
# shruthi
