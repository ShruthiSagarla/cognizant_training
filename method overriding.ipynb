# %%
class Parent:
  def func1(self):
      print("This function is in parent class")         #single inheritance
class child(Parent):
    def func1(self):
      print("This function is in child class")
object=child()
object.func1()
# Out:
# This function is in child class
