# %%
print(10+20)
print("shruthi"+"mudhiraj")
# Out:
# 30
# shruthimudhiraj

# %%
class Student:                              
  def __init__ (self,marks):        #custom operator
    self.marks = marks

  def __add__ (self,other):
    return self.marks+other.marks

s1 = Student(80)
s2 = Student(75)
print(s1+s2)
# Out:
# 155
