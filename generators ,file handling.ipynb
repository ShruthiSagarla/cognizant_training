# %%
def numbers():
    
    yield 1
    yield 2
    yield 3                       #generators

gen = numbers()
print(next(gen))
print(next(gen))
print(next(gen))
# Out:
# 1
# 2
# 3

# %%
file = open("demo.txt","w")
file.write("hello siri")
file.close()
                                               #file handling
file = open("demo.txt","r")
file.read()
# Out:
# 'hello siri'

# %%
file = open("demo.txt","r")
content = file.read()
print(content)
# Out:
# hello siri
