# %%
name="shruthi"
print(name)
# Out:
# shruthi

# %%
name="shruthi"
email="sagarlashruthi@gmail.com"
print(name) 
print(email)
# Out:
# shruthi
# sagarlashruthi@gmail.com

# %%
city="pune"
print(city[2])
print(city[-1])
# Out:
# n
# e

# %%
name="shruthi"
print(name[1:4])
# Out:
# hru

# %%
name="shruthi"
print(len(name))
# Out:
# 7

# %%
s="hello"
print(s*3)
# Out:
# hellohellohello

# %%
p="shruthi"
print(p.upper())
# Out:
# SHRUTHI

# %%
p="SHRUTHI"
print(p.lower())
# Out:
# shruthi

# %%
s=" I Like Java"
print(s.replace("Java","python"))
# Out:
#  I Like python

# %%
s="anything something"
print(s.find("something"))
# Out:
# 9

# %%
name=input("Enter the name :")
print("welcome",name)
# Out:
# Enter the name : siri
# welcome siri

# %%
s="SHRUTHI"
print(p[::-1])
# Out:
# IHTURHS

# %%
name="shruthi"
def greet():
    
    print("hello",name)
   
greet()
# Out:
# hello shruthi
