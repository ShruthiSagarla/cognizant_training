# %%
try:
    num=19
    print(num/0)                            
except ZeroDivisionError:
    print("cannot divide by zero")
# Out:
# cannot divide by zero

# %%
try:
    s = int(input("enter the age :"))
except ValueError:
    print(age)
# Out:
# enter the age : 19

# %%
try:
    num=int(input("enter the number :"))             #multiple handling
    print(10/num)
except ValueError:
    print("Number can't be divided")
except ZeroDivisionError:
    print("Zero can't be divided!")
# Out:
# enter the number : 0.3
# Number can't be divided
